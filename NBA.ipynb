# %%
# !pip install boto3 pandas
# Out:
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.11/site-packages (1.34.131)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: botocore<1.35.0,>=1.34.131 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.34.131)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from boto3) (0.10.2)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.131->boto3) (1.26.19)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import boto3
import pandas as pd

# Initialize a session using your S3 bucket
s3 = boto3.client('s3')

# Set your bucket name and file path (replace these with your actual details)
bucket_name = 'nbaallstar'
file_key = 'nba.csv'

# Download the file from S3 to the SageMaker notebook instance
s3.download_file(bucket_name, file_key, 'nba_file.csv')

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('nba_file.csv')

# Display the first few rows
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
import sagemaker
from sagemaker.sklearn.estimator import SKLearn

# Define the S3 paths for input and output
bucket_name = 'your-s3-bucket-name'
training_data_s3_path = f's3://nbaallstar/nba.csv'
output_model_s3_path = f's3://nbaallstar/output'

# Initialize SageMaker session
sagemaker_session = sagemaker.Session()

# Define the estimator for running the training job
sklearn_estimator = SKLearn(
    entry_point='train.py',  # Path to your train.py
    role='arn:aws:iam::767398042415:role/service-role/AmazonSageMaker-ExecutionRole-20240919T115649',  # Replace with your SageMaker execution role ARN
    instance_count=1,
    instance_type='ml.m5.large',  # Adjust the instance type as needed
    framework_version='0.23-1',   # Version of scikit-learn
    output_path=output_model_s3_path,  # Where the trained model will be saved
    sagemaker_session=sagemaker_session
)

# Launch the training job
sklearn_estimator.fit({'training': training_data_s3_path})
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-scikit-learn-2024-10-02-08-36-07-258
# 2024-10-02 08:36:07 Starting - Starting the training job...
# 2024-10-02 08:36:30 Starting - Preparing the instances for training...
# 2024-10-02 08:36:53 Downloading - Downloading input data...
# 2024-10-02 08:37:18 Downloading - Downloading the training image...
# 2024-10-02 08:38:10 Training - Training image download completed. Training in progress.
# 2024-10-02 08:38:10 Uploading - Uploading generated training model2024-10-02 08:38:04,394 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2024-10-02 08:38:04,398 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-10-02 08:38:04,448 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2024-10-02 08:38:04,601 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-10-02 08:38:04,615 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-10-02 08:38:04,628 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-10-02 08:38:04,637 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2024-10-02-08-36-07-258",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://nbaallstar/sagemaker-scikit-learn-2024-10-02-08-36-07-258/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://nbaallstar/sagemaker-scikit-learn-2024-10-02-08-36-07-258/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2024-10-02-08-36-07-258","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://nbaallstar/sagemaker-scikit-learn-2024-10-02-08-36-07-258/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python train.py
# Input data path: /opt/ml/input/data/training
# Model output path: /opt/ml/model
# Error loading dataset: [Errno 2] No such file or directory: '/opt/ml/input/data/training/nba_file.csv'
# Traceback (most recent call last):
#   File "train.py", line 16, in <module>
#     df = pd.read_csv(os.path.join(input_data_path, 'nba_file.csv'))
#   File "/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 1178, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py", line 2008, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
#   File "pandas/_libs/parsers.pyx", line 382, in pandas._libs.parsers.TextReader.__cinit__
#   File "pandas/_libs/parsers.pyx", line 674, in pandas._libs.parsers.TextReader._setup_parser_source
# FileNotFoundError: [Errno 2] No such file or directory: '/opt/ml/input/data/training/nba_file.csv'
# 2024-10-02 08:38:05,687 sagemaker-containers ERROR    Reporting training FAILURE
# 2024-10-02 08:38:05,687 sagemaker-containers ERROR    framework error:
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_trainer.py", line 84, in train
#     entrypoint()
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_sklearn_container/training.py", line 39, in main
#     train(environment.Environment())
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_sklearn_container/training.py", line 35, in train
#     runner_type=runner.ProcessRunnerType)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/entry_point.py", line 100, in run
#     wait, capture_error
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/process.py", line 291, in run
#     cwd=environment.code_dir,
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/process.py", line 208, in check_error
#     info=extra_info,
# sagemaker_training.errors.ExecuteUserScriptError: ExecuteUserScriptError:
# ExitCode 1
# ErrorMessage ""
# Command "/miniconda3/bin/python train.py"
# ExecuteUserScriptError:
# ExitCode 1
# ErrorMessage ""
# Command "/miniconda3/bin/python train.py"
#
# 2024-10-02 08:38:23 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# Cell In[7], line 24
#      13 sklearn_estimator = SKLearn(
#      14     entry_point='train.py',  # Path to your train.py
#      15     role='arn:aws:iam::767398042415:role/service-role/AmazonSageMaker-ExecutionRole-20240919T115649',  # Replace with your SageMaker execution role ARN
#    (...)
#      20     sagemaker_session=sagemaker_session
#      21 )
#      23 # Launch the training job
# ---> 24 sklearn_estimator.fit({'training': training_data_s3_path})
#
# File /opt/conda/lib/python3.11/site-packages/sagemaker/workflow/pipeline_context.py:346, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     342         return context
#     344     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 346 return run_func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/sagemaker/estimator.py:1350, in EstimatorBase.fit(self, inputs, wait, logs, job_name, experiment_config)
#    1348 self.jobs.append(self.latest_training_job)
#    1349 if wait:
# -> 1350     self.latest_training_job.wait(logs=logs)
#
# File /opt/conda/lib/python3.11/site-packages/sagemaker/estimator.py:2720, in _TrainingJob.wait(self, logs)
#    2718 # If logs are requested, call logs_for_jobs.
#    2719 if logs != "None":
# -> 2720     self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    2721 else:
#    2722     self.sagemaker_session.wait_for_job(self.job_name)
#
# File /opt/conda/lib/python3.11/site-packages/sagemaker/session.py:5853, in Session.logs_for_job(self, job_name, wait, poll, log_type, timeout)
#    5832 def logs_for_job(self, job_name, wait=False, poll=10, log_type="All", timeout=None):
#    5833     """Display logs for a given training job, optionally tailing them until job is complete.
#    5834
#    5835     If the output is a tty or a Jupyter cell, it will be color-coded
#    (...)
#    5851         exceptions.UnexpectedStatusException: If waiting and the training job fails.
#    5852     """
# -> 5853     _logs_for_job(self, job_name, wait, poll, log_type, timeout)
#
# File /opt/conda/lib/python3.11/site-packages/sagemaker/session.py:8455, in _logs_for_job(sagemaker_session, job_name, wait, poll, log_type, timeout)
#    8452             last_profiler_rule_statuses = profiler_rule_statuses
#    8454 if wait:
# -> 8455     _check_job_status(job_name, description, "TrainingJobStatus")
#    8456     if dot:
#    8457         print()
#
# File /opt/conda/lib/python3.11/site-packages/sagemaker/session.py:8508, in _check_job_status(job, desc, status_key_name)
#    8502 if "CapacityError" in str(reason):
#    8503     raise exceptions.CapacityError(
#    8504         message=message,
#    8505         allowed_statuses=["Completed", "Stopped"],
#    8506         actual_status=status,
#    8507     )
# -> 8508 raise exceptions.UnexpectedStatusException(
#    8509     message=message,
#    8510     allowed_statuses=["Completed", "Stopped"],
#    8511     actual_status=status,
#    8512 )
#
# UnexpectedStatusException: Error for Training job sagemaker-scikit-learn-2024-10-02-08-36-07-258: Failed. Reason: AlgorithmError: framework error:
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_trainer.py", line 84, in train
#     entrypoint()
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_sklearn_container/training.py", line 39, in main
#     train(environment.Environment())
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_sklearn_container/training.py", line 35, in train
#     runner_type=runner.ProcessRunnerType)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/entry_point.py", line 100, in run
#     wait, capture_error
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/process.py", line 291, in run
#     cwd=environment.code_dir,
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/process.py", line 208, in check_error
#     info=extra_info,
# sagemaker_training.errors.ExecuteUserScriptError: ExecuteUserScriptError:
# ExitCode 1
# ErrorMessage ""
# Command "/miniconda3/bin/python train.py"
#
# ExecuteUserScriptErro
